# %%
from matplotlib import pyplot as plt
import numpy as np
from scipy.signal import savgol_filter
from tqdm import tqdm
import os

# %%
def sample(s, slen,  points=200):
    try:
        window_length = slen//15*2+1
        s=savgol_filter(s,  window_length, 2)
        s=savgol_filter(s,  window_length, 2)
        step = slen//points
        idx = [step*i for i in range(points)]
        return s[idx]
    except:
        return None

# %%
# a = np.load('/Users/zinccat/Documents/挑战杯/output_newdict_0405/2005-30本/又一春by大风刮过.npz')
a = np.load('/Users/zinccat/Documents/挑战杯/output_newdict_0405/2020-50本/难哄by竹已.npz')

# %%
samp = sample(a['arr_0'], len(a['arr_0']))

# %%
plt.plot(samp)
